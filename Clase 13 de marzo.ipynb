# %% [markdown]
# # Clase 13 de marzo (Generación de graficos y librerias necesarias)

# %% [markdown]
# ## Grafico de dispersion de puntos

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
ax.scatter([10,20,30],[5,10,2])
plt.show()

# %% [markdown]
# ## Grafico de dispersion de lineas

# %%
fig,ax=plt.subplots()
ax.plot([10,20,30,40],[1,5,9,9])
plt.show()

# %% [markdown]
# ## Representación area debajo de curvas

# %%
fig,ax=plt.subplots()
ax.fill_between([10,20,30,40],[20,50,60,5])
plt.show()

# %% [markdown]
# ## Diagrama de barras

# %%
fig,ax=plt.subplots()
ax.bar([1,2,3,4],[10,20,30,5])
plt.show()

# %% [markdown]
# ## Grafico de contorno

# %%
import numpy as np

fig,ax=plt.subplots()
x=np.linspace(-3,3,100)
y=np.linspace(-3,3,100)
x,y=np.meshgrid(x,y)
z=np.sqrt(x**2 + y**2)
ax.contourf(x,y,z)
plt.show()

# %% [markdown]
# ## Grafico completo

# %%
#Grafico mas completo

fig,ax=plt.subplots(figsize=(15,10))
dias=["L","Ma","Mi","J","V","S","D"]
temperaturas={"Medellin":[14,15,13,20,15,16,2],"Bogota":[5,6,7,10,15,6,9]}
ax.plot(dias,temperaturas["Medellin"],color="tab:purple",marker="*",linestyle="dashed",label="Medellin")
ax.plot(dias,temperaturas["Bogota"],color="tab:green",marker="o",linestyle="dotted",label="Bogota")
ax.set_title("Evolucion de la temperatura en Colombia",fontdict={"fontsize":14,"fontweight":"bold","color":"tab:red"})
ax.set_xlabel("Dias",fontdict={"fontsize":14,"fontweight":"bold","color":"tab:red"})
ax.set_ylabel("Temperaturas",fontdict={"fontsize":14,"fontweight":"bold","color":"tab:red"})
ax.grid()
ax.legend()
plt.show()

# %% [markdown]
# # Ciencias de datos

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use("ggplot")
datos=pd.read_excel("winequality.xlsx")
datos
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
datos.iloc[10]
# Out:
# fixed acidity            6.7000
# volatile acidity         0.5800
# citric acid              0.0800
# residual sugar           1.8000
# chlorides                0.0970
# free sulfur dioxide     15.0000
# total sulfur dioxide    65.0000
# density                  0.9959
# pH                       3.2800
# sulphates                0.5400
# alcohol                  9.2000
# quality                  5.0000
# Name: 10, dtype: float64

# %%
datos.fillna(0)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
rango=datos.loc[0:20]
rango
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
rango.plot(x="residual sugar",y="quality",kind="bar",figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='residual sugar'>

# %%
rango1=datos.loc[datos["quality"]==8] #probar con 10 y 9
rango1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267             7.9              0.35         0.46             3.6      0.078
# 278            10.3              0.32         0.45             6.4      0.073
# 390             5.6              0.85         0.05             1.4      0.045
# 440            12.6              0.31         0.72             2.2      0.072
# 455            11.3              0.62         0.67             5.2      0.086
# 481             9.4              0.30         0.56             2.8      0.080
# 495            10.7              0.35         0.53             2.6      0.070
# 498            10.7              0.35         0.53             2.6      0.070
# 588             5.0              0.42         0.24             2.0      0.060
# 828             7.8              0.57         0.09             2.3      0.065
# 1061            9.1              0.40         0.50             1.8      0.071
# ...

# %%
rango1.plot(x="alcohol",y="citric acid") #Desorden
# Out:
# <AxesSubplot:xlabel='alcohol'>

# %%
Orden=rango1.sort_values(by=["alcohol"]) #Los ordena de forma descendente
Orden.plot(x="alcohol",y="citric acid",kind="bar",figsize=(10,10),color="black")
plt.xticks(rotation=45,horizontalalignment="center")
plt.title("Alcohol vs acido citrico")
plt.xlabel("Alcohol")
plt.ylabel("Acido citrico")
plt.show()

# %%
Orden.plot(x="alcohol",y=["citric acid","residual sugar"],kind="bar",color=["grey","black"],figsize=(15,15))
plt.show()

# %%
datos.sample(5) #Me arroja una cantidad n aleatorios
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 152            7.5              0.60         0.03             1.8      0.095
# 50             8.8              0.66         0.26             1.7      0.074
# 603           13.2              0.46         0.52             2.2      0.071
# 592            9.0              0.45         0.49             2.6      0.084
# 84             6.3              0.30         0.48             1.8      0.069
#
#      free sulfur dioxide  total sulfur dioxide     density    pH  sulphates  \
# 152                 25.0                  99.0      0.9950  3.35       0.54
# 50                   4.0                  23.0      0.9971  3.15       0.74
# 603                 12.0                  35.0  10006.0000  3.10       0.56
# 592                 21.0                  75.0      0.9987  3.35       0.57
# 84                  18.0                  61.0      0.9959  3.44       0.78
#
#      alcohol  quality
# 152     10.1        5
# ...

# %%
datos.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          3.879687     0.270976        2.538806
# std         1.741096         60.015370     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000       1185.000000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide       density  \
# count  1599.000000          1599.000000           1599.000000  1.599000e+03
# mean      0.087467            15.874922             46.467792  6.254659e+12
# std       0.047065            10.460157             32.895324  2.501082e+14
# ...

# %%
 datos.isna().sum() #Me determina si existen valores con valor NAN dentro de los datos
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import seaborn as sns #ibreria para visualizar datos en python de forma mas profesional 

datos_cortados=datos.loc[0:200]
graf=datos_cortados.columns.to_list() #Me organiza los datos dentro de una lista pero por columna
fig,ax=plt.subplots(3,4,figsize=(15,15))
for valor,titulo in enumerate(graf):
    i=valor//4
    j=valor%4
    
    sns.histplot(x=titulo,kde=True,data=datos_cortados,ax=ax[i][j]) #kde=metodo para visualizar la distribucion
    
    ax[i][j].set_title(titulo+ "Descripcion")
    ax[i][j].set_ylabel(titulo)
plt.show()

# %%
lista=["fixed acidity","volatile acidity","chlorides","density"]
fig,ax=plt.subplots(1,4,figsize=(15,15))
for valor,titulo in enumerate(lista):
    sns.boxplot(y=titulo,ax=ax[valor],data=datos)
plt.show()

# %%
sns.scatterplot(x="free sulfur dioxide",y="total sulfur dioxide",data=datos)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='total sulfur dioxide'>

# %%
correlation=datos.corr(method="pearson")
correlation.head()
# Out:
#                   fixed acidity  volatile acidity  citric acid  \
# fixed acidity          1.000000         -0.001996     0.671703
# volatile acidity      -0.001996          1.000000    -0.033493
# citric acid            0.671703         -0.033493     1.000000
# residual sugar         0.114777          0.044796     0.143577
# chlorides              0.093705          0.000546     0.203823
#
#                   residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity           0.114777   0.093705            -0.153794
# volatile acidity        0.044796   0.000546            -0.029612
# citric acid             0.143577   0.203823            -0.060978
# residual sugar          1.000000   0.055610             0.187049
# chlorides               0.055610   1.000000             0.005562
#
#                   total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                -0.113181  0.065830 -0.682978   0.183006
# ...

# %%
fig,ax=plt.subplots(figsize=(12,12))
sns.heatmap(vmin=-1,annot=True,data=correlation,cmap="coolwarm") #annot=Metodo para visualiar los datos
plt.show()
